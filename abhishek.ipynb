# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekkothamasu/Data-Science-Project-1/blob/main/abhishek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("maa.csv")
x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attribution']
df.dropna()
df.drop_duplicates()
df['BussinessTravel']=lb().fit_transform(df['BussinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-13-61d1513481c1> in <cell line: 5>()
#       3 import seaborn as sbn
#       4 from sklearn.preprocessing import LabelEncoder as lb
# ----> 5 df=pd.read_csv("maa.csv")
#       6 x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
#       7 y=df['Attribution']
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("maa.csv")
x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attribution']
df.dropna()
df.drop_duplicates()
df['BussinessTravel']=lb().fit_transform(df['BussinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Attribution'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("maa.csv")
x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attribution']
df.dropna()
df.drop_duplicates()
df['BussinessTravel']=lb().fit_transform(df['BussinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-18-61d1513481c1> in <cell line: 5>()
#       3 import seaborn as sbn
#       4 from sklearn.preprocessing import LabelEncoder as lb
# ----> 5 df=pd.read_csv("maa.csv")
#       6 x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
#       7 y=df['Attribution']
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("/content/maa.csv")
x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',
      'EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement',
      'JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18',
      'OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel',
      'TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attrition']
df.info()
print(df.head())
print(df.isnull())
plt.figure(figsize=(12,9))
sns.countplot(x='Attrition',data=df)
plt.title("distribution of attrition ")
plt.show()
plt.figure(figsize=(12,9))
sns.boxplot(x='Attrition',y="Age",data=df)
plt.title("attrition vs age")
plt.show()
df.dropna()
df.drop_duplicates()
df['BusinessTravel']=lb().fit_transform(df['BusinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head(10))
df.info()
gender_dictonary={
    'Female':1,
    'Male':0
}
df['Gender']=df['Gender'].map(gender_dictonary)
dept_dict={
    'Sales':1,
    'Research & Development':2,
    'Human Resource':3
}
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("/maa.csv")
x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',
      'EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement',
      'JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18',
      'OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel',
      'TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attrition']
df.info()
print(df.head())
print(df.isnull())
plt.figure(figsize=(12,9))
sns.countplot(x='Attrition',data=df)
plt.title("distribution of attrition ")
plt.show()
plt.figure(figsize=(12,9))
sns.boxplot(x='Attrition',y="Age",data=df)
plt.title("attrition vs age")
plt.show()
df.dropna()
df.drop_duplicates()
df['BusinessTravel']=lb().fit_transform(df['BusinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head(10))
df.info()
gender_dictonary={
    'Female':1,
    'Male':0
}
df['Gender']=df['Gender'].map(gender_dictonary)
dept_dict={
    'Sales':1,
    'Research & Development':2,
    'Human Resource':3
}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-3206afe4f4ea> in <cell line: 5>()
#       3 import seaborn as sns
#       4 from sklearn.preprocessing import LabelEncoder as lb
# ----> 5 df=pd.read_csv("/maa.csv")
#       6 x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',
#       7       'EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement',
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("/content/maa.csv")
x=df[['Age','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField',
      'EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement',
      'JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18',
      'OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours','StockOptionLevel',
      'TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attrition']
df.info()
print(df.head())
print(df.isnull())
plt.figure(figsize=(12,9))
sns.countplot(x='Attrition',data=df)
plt.title("distribution of attrition ")
plt.show()
plt.figure(figsize=(12,9))
sns.boxplot(x='Attrition',y="Age",data=df)
plt.title("attrition vs age")
plt.show()
df.dropna()
df.drop_duplicates()
df['BusinessTravel']=lb().fit_transform(df['BusinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head(10))
df.info()
gender_dictonary={
    'Female':1,
    'Male':0
}
df['Gender']=df['Gender'].map(gender_dictonary)
dept_dict={
    'Sales':1,
    'Research & Development':2,
    'Human Resource':3
}
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.preprocessing import LabelEncoder as lb
df=pd.read_csv("/content/maa.csv")
plt.figure(figsize=(12,9))
sns.countplot(x='Attrition',data=df)
plt.title('Distribution over Attrition')
plt.show()
plt.figure(figsize=(12,9))
sns.histplot(df['Age'],bins=20,kde=True)
plt.title('Distribution over Age')
plt.show()
plt.figure(figsize=(12,9))
sns.boxplot(x='Attrition',y='Age',data=df)
plt.title('Age vs Attrition')
plt.show()
x=df[['Age','Attrition','BusinessTravel','DailyRate','Department','DistanceFromHome','Education','EducationField','EmployeeCount','EmployeeNumber','EnvironmentSatisfaction','Gender','HourlyRate','JobInvolvement','JobLevel','JobRole','JobSatisfaction','MaritalStatus','MonthlyIncome','MonthlyRate','NumCompaniesWorked','Over18','OverTime','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StandardHours'
,'StockOptionLevel','TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]
y=df['Attrition']
df.dropna()
df.drop_duplicates()
df['BusinessTravel']=lb().fit_transform(df['BusinessTravel'])
df['Attrition']=lb().fit_transform(df['Attrition'])
print(df.head())
gender_dictionary={
    'Female':1,
    'Male':0
}
df['Gender']=df['Gender'].map(gender_dictionary)
print(df['Department'].unique())
dept_dict={
    'Sales':1,
    'Research and Development':2,
    'Human Resopurces':3
}
df['Department']=df['Department'].map(dept_dict)
print(df.head())
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               2       1102                   Sales
# 1   49          0               1        279  Research & Development
# 2   37          1               2       1373  Research & Development
# 3   33          0               1       1392  Research & Development
# 4   27          0               2        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
from keras.models import seque

# %%
a=int(input())
b=int(input())
c=int(input())
if(a+b)>=c:
    if(b+c)>=a:
        if(a+c)>=b:
            print("traingle is formed")
        else:
                print("traingle is not formed")
    else:
        print("traingle is not formed")
else:
    print("traingle is not formed")
# Out:
# 10
# 3
# 1
# traingle is not formed

# %%
w=float(input())
if w>0 and w<=2000:
  print("2 hours")
elif w>2000 and w<=4000:
  print("3 hours")
elif w>4000 and w<=7000:
  print("4 hours")
else:
  print("over weight")
# Out:
# 1
# 2 hours

# %%
import pandas as pd
data1={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,22,32],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Msc','MA','MCA','Phd']}
data2={'Name':['Abhi','Ayushi','Dhiraj','Hitesh'],'Age':[17,14,12,52],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Btech','B.A','Bcom','B.hons']}
df=pd.DataFrame(data1,index=[0,1,2,3])
df1=pd.DataFrame(data2,index=[4,5,6,7])
print(df,"\n\n",df1)
frames=[df,df1]
res1=pd.concat([df,df1])
print(res1)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd
#
#       Name  Age    Address Qualification
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannauj        B.hons
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd
# 4    Abhi   17     Nagpur         Btech
# 5  Ayushi   14     Kanpur           B.A
# 6  Dhiraj   12  Allahabad          Bcom
# 7  Hitesh   52    Kannauj        B.hons

# %%
data1={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,22,32],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Msc','MA','MCA','Phd'],'salary':[1000,2000,3000,4000]}
data2={'Name':['Abhi','Ayushi','Dhiraj','Hitesh'],'Age':[17,14,12,52],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Btech','B.A','Bcom','B.hons'],'salary':[1000,2000,3000,4000]}
df=pd.DataFrame(data1,index=[0,1,2,3])
df1=pd.DataFrame(data2,index=[2,3,6,7])
print(df,"\n\n",df1)
res2=pd.concat([df,df1],axis=1,join='inner')
print(res2)
# Out:
#      Name  Age    Address Qualification  salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannauj           Phd    4000
#
#       Name  Age    Address Qualification  salary
# 2    Abhi   17     Nagpur         Btech    1000
# 3  Ayushi   14     Kanpur           B.A    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannauj        B.hons    4000
#      Name  Age    Address Qualification  salary    Name  Age Address  \
# 2  Gaurav   22  Allahabad           MCA    3000    Abhi   17  Nagpur
# 3    Anuj   32    Kannauj           Phd    4000  Ayushi   14  Kanpur
#
#   Qualification  salary
# 2         Btech    1000
# 3           B.A    2000

# %%
data1={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,22,32],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Msc','MA','MCA','Phd'],'salary':[1000,2000,3000,4000]}
data2={'Name':['Abhi','Ayushi','Dhiraj','Hitesh'],'Age':[17,14,12,52],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Btech','B.A','Bcom','B.hons'],'salary':[1000,2000,3000,4000]}
df=pd.DataFrame(data1,index=[0,1,2,3])
df1=pd.DataFrame(data2,index=[2,3,6,7])
print(df,"\n\n",df1)
# Out:
#      Name  Age    Address Qualification  salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannauj           Phd    4000
#
#       Name  Age    Address Qualification  salary
# 2    Abhi   17     Nagpur         Btech    1000
# 3  Ayushi   14     Kanpur           B.A    2000
# 6  Dhiraj   12  Allahabad          Bcom    3000
# 7  Hitesh   52    Kannauj        B.hons    4000

# %%
data1={'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,22,32],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Msc','MA','MCA','Phd']}
df=pd.DataFrame(data1,index=[0,1,2,3])
s1=pd.Series([1000,2000,3000,4000],name='salary')
print(df,"\n\n",s1)
res=pd.concat([df,s1],axis=1)
print(res)
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd
#
#  0    1000
# 1    2000
# 2    3000
# 3    4000
# Name: salary, dtype: int64
#      Name  Age    Address Qualification  salary
# 0     Jai   27     Nagpur           Msc    1000
# 1  Princi   24     Kanpur            MA    2000
# 2  Gaurav   22  Allahabad           MCA    3000
# 3    Anuj   32    Kannauj           Phd    4000

# %%
data1={'key':['K0','K1','K2','K3'],'Name':['Jai','Princi','Gaurav','Anuj'],'Age':[27,24,22,32]}
df=pd.DataFrame(data1)
data2={'key':['k0','k1','k2','k3'],'Address':['Nagpur','Kanpur','Allahabad','Kannauj'],'Qualification':['Btech','B.A','Bcom','B.hons']}
df1=pd.DataFrame(data2)
print(df,"\n\n",df1)
res1=pd.merge(df,df1,on='key')
print(res1)
# Out:
#   key    Name  Age
# 0  K0     Jai   27
# 1  K1  Princi   24
# 2  K2  Gaurav   22
# 3  K3    Anuj   32
#
#    key    Address Qualification
# 0  k0     Nagpur         Btech
# 1  k1     Kanpur           B.A
# 2  k2  Allahabad          Bcom
# 3  k3    Kannauj        B.hons
# Empty DataFrame
# Columns: [key, Name, Age, Address, Qualification]
# Index: []

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

# %%
path="/content/drive/MyDrive/energy.csv"
electricity=pd.read_csv(path)

print(electricity)
print(electricity.shape)
print(electricity.head(5))
print(electricity.tail(4))
print(electricity.info())
print(electricity.describe())

print("column Data")
print(electricity.columns)
print(electricity[electricity['State'].str.startswith('M')])
print(electricity[electricity['State'].str.endswith('a')])
rcb=electricity[electricity['State']=='Andhra']
print(len(rcb))

print(np.max(electricity['Consumption']))
print(np.min(electricity['Consumption']))
print(np.mean(electricity['Consumption']))

state1_data=electricity[electricity['State']=='Andhra']
print("Andhra data")
print(state1_data)
state2_data=electricity[electricity['State']=='Karnataka']
state4_data=electricity[electricity['State']=='Telangana']
state5_data=electricity[electricity['State']=='Tripura']

fig, axes=plt.subplots(2)
axes[0].plot(state1_data['Date'],state1_data['Consumption'],color='red')
axes[1].plot(state2_data['Date'],state1_data['Consumption'],color='green')

fig1, axes1 = plt.subplots(2)
axes1[0].bar(state1_data['Date'],state1_data['Consumption'],color='blue')
axes1[1].bar(state2_data['Date'],state2_data['Consumption'],color='pink')

fig2,axes2 =plt.subplots(2)
State1='UP'
State2='kerala'
State3='Mizoram'
State4='Delhi'

labels=[state1,state2]
state1_total=electricity[electricity['State']==state1]['Consumption'].sum()
state2_total=electricity[electricity['State']==state2]['Consumption'].sum()

energy=[state1_total,state2_total]
axes2[0].pie(energy,labels=labels,autopct='%1.1f%%')
# Out:
#           Date        State  Consumption
# 0   01-01-2024    Tamilnadu       347.25
# 1   02-01-2024      Manipur       605.12
# 2   03-01-2024    Telengana       444.63
# 3   04-01-2024  Pondicherry       974.54
# 4   05-01-2024    Tamilnadu       864.02
# ..         ...          ...          ...
# 95  05-04-2024       Kerala       587.30
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# 99  09-04-2024  Pondicherry       983.95
#
# [100 rows x 3 columns]
# (100, 3)
#          Date        State  Consumption
# 0  01-01-2024    Tamilnadu       347.25
# 1  02-01-2024      Manipur       605.12
# 2  03-01-2024    Telengana       444.63
# 3  04-01-2024  Pondicherry       974.54
# 4  05-01-2024    Tamilnadu       864.02
#           Date        State  Consumption
# 96  06-04-2024           UP       726.21
# 97  07-04-2024       Andhra       305.70
# 98  08-04-2024       Sikkim       257.46
# ...
